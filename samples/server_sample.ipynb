# %%
from iclientpy import rest

# %%
server = rest.Server(base_url="http://support.supermap.com.cn:8090/iserver")

# %%
services = server.servicespage()

# %%
services = services.list_services()

# %%
services
# Out:
# [{
#    "componentType": "com.supermap.services.components.impl.RealspaceImpl",
#    "interfaceType": "com.supermap.services.rest.RestServlet",
#    "name": "3D-CBD/rest",
#    "url": "http://support.supermap.com.cn:8090/iserver/services/3D-CBD/rest"
#  }, {
#    "componentType": "com.supermap.services.components.impl.AddressMatchImpl",
#    "interfaceType": "com.supermap.services.rest.JaxrsServletForJersey",
#    "name": "addressmatch-Address/restjsr",
#    "url": "http://support.supermap.com.cn:8090/iserver/services/addressmatch-Address/restjsr"
#  }, {
#    "componentType": "componentSetType",
#    "interfaceType": "com.supermap.services.handler.HandlerServlet",
#    "name": "components-handler/handler",
#    "url": "http://support.supermap.com.cn:8090/iserver/services/components-handler/handler"
#  }, {
#    "componentType": "componentSetType",
#    "interfaceType": "com.supermap.services.rest.RestServlet",
#    "name": "components-rest/rest",
# ...

# %%
maps_rest = server.map_service("maps/rest")

# %%
maps_rest.get_map_resources()
# Out:
# [{
#    "name": "\u4e16\u754c\u5730\u56fe_Day",
#    "path": "http://support.supermap.com.cn:8090/iserver/services/maps/rest/maps/%E4%B8%96%E7%95%8C%E5%9C%B0%E5%9B%BE_Day"
#  }, {
#    "name": "World",
#    "path": "http://support.supermap.com.cn:8090/iserver/services/maps/rest/maps/World"
#  }, {
#    "name": "\u4e16\u754c\u5730\u56fe_Gray",
#    "path": "http://support.supermap.com.cn:8090/iserver/services/maps/rest/maps/%E4%B8%96%E7%95%8C%E5%9C%B0%E5%9B%BE_Gray"
#  }, {
#    "name": "\u4e16\u754c\u5730\u56fe",
#    "path": "http://support.supermap.com.cn:8090/iserver/services/maps/rest/maps/%E4%B8%96%E7%95%8C%E5%9C%B0%E5%9B%BE"
#  }, {
#    "name": "World Map",
#    "path": "http://support.supermap.com.cn:8090/iserver/services/maps/rest/maps/World%20Map"
#  }, {
#    "name": "\u4e16\u754c\u5730\u56fe_Night",
#    "path": "http://support.supermap.com.cn:8090/iserver/services/maps/rest/maps/%E4%B8%96%E7%95%8C%E5%9C%B0%E5%9B%BE_Night"
#  }, {
#    "name": "World_Common",
# ...

# %%
maps_rest.get_map("World_Common")
# Out:
# {<br/>&nbsp;&nbsp;"angle":&nbsp;0,<br/>&nbsp;&nbsp;"antialias":&nbsp;true,<br/>&nbsp;&nbsp;"autoAvoidEffectEnabled":&nbsp;true,<br/>&nbsp;&nbsp;"backgroundStyle":&nbsp;{<br/>&nbsp;&nbsp;&nbsp;&nbsp;"fillBackColor":&nbsp;{<br/>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;"alpha":&nbsp;255,<br/>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;"blue":&nbsp;255,<br/>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;"green":&nbsp;255,<br/>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;"red":&nbsp;255<br/>&nbsp;&nbsp;&nbsp;&nbsp;},<br/>&nbsp;&nbsp;&nbsp;&nbsp;"fillBackOpaque":&nbsp;true,<br/>&nbsp;&nbsp;&nbsp;&nbsp;"fillForeColor":&nbsp;{<br/>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;"alpha":&nbsp;255,<br/>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;"blue":&nbsp;255,<br/>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;"green":&nbsp;255,<br/>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;"red":&nbsp;255<br/>&nbsp;&nbsp;&nbsp;&nbsp;},<br/>&nbsp;&nbsp;&nbsp;&nbsp;"fillGradientAngle":&nbsp;0,<br/>&nbsp;&nbsp;&nbsp;&nbsp;"fillGradientMode":&nbsp;"NONE",<br/>&nbsp;&nbsp;&nbsp;&
# ...
